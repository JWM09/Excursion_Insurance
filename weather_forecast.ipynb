# %%
# Import Required Libraries
import pandas as pd
import requests
import json
import os
from dotenv import load_dotenv

# %%
# Load .env environment variables into the notebook
load_dotenv()
# Out:
# True

# %%
#hnl_api_key = os.getenv('HNL_Weather')

# %%
#type(hnl_api_key)

# %%
#define th base request URL
hnl_url = 'https://api.openweathermap.org/data/3.0/onecall?lat=21.31&lon=-157.86&exclude=alrets&appid=9dd666c40323f8e9c4e096ee0947bfad'

# %%
# concatenate with api key
#hnl_weather_request = hnl_url + hnl_api_key

# %%
# execute api call
#weather_forecast = requests.get(hnl_weather_request).json()
weather_forecast = requests.get(hnl_url).json()

# %%
# Display Response
print(json.dumps(weather_forecast, indent=4, sort_keys=True))
# Out:
# {
#     "alerts": [
#         {
#             "description": "...SMALL CRAFT ADVISORY NOW IN EFFECT UNTIL 6 PM HST WEDNESDAY...\n* WHAT...East winds 20 to 25 kt and seas 6 to 9 feet.\n* WHERE...Oahu Windward Waters, Oahu Leeward Waters, Kaiwi\nChannel, Maui County Windward Waters, Maui County Leeward\nWaters, Maalaea Bay, Pailolo Channel, Alenuihaha Channel, Big\nIsland Windward Waters, Big Island Leeward Waters and Big\nIsland Southeast Waters.\n* WHEN...Until 6 PM HST Wednesday.\n* IMPACTS...Conditions will be hazardous to small craft.",
#             "end": 1666843200,
#             "event": "Small Craft Advisory",
#             "sender_name": "NWS Honolulu (Hawaii)",
#             "start": 1666746660,
#             "tags": []
#         }
#     ],
#     "current": {
#         "clouds": 40,
#         "dew_point": 295.49,
#         "dt": 1666754233,
#         "feels_like": 303.45,
#         "humidity": 73,
#         "pressure": 1017,
#         "sunrise": 1666715465,
#         "sunset": 1666756777,
#         "temp": 300.77,
#         "uvi": 0.6,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "scattered clouds",
#                 "icon": "03d",
#                 "id": 802,
#                 "main": "Clouds"
#             }
#         ],
#         "wind_deg": 60,
#         "wind_speed": 5.14
#     },
#     "daily": [
#         {
#             "clouds": 1,
#             "dew_point": 294.81,
#             "dt": 1666735200,
#             "feels_like": {
#                 "day": 302.54,
#                 "eve": 302.88,
#                 "morn": 299.29,
#                 "night": 299.71
#             },
#             "humidity": 73,
#             "moon_phase": 0,
#             "moonrise": 1666716540,
#             "moonset": 1666758420,
#             "pop": 0.09,
#             "pressure": 1018,
#             "sunrise": 1666715465,
#             "sunset": 1666756777,
#             "temp": {
#                 "day": 300.3,
#                 "eve": 300.43,
#                 "max": 300.77,
#                 "min": 298.65,
#                 "morn": 298.65,
#                 "night": 298.98
#             },
#             "uvi": 8.38,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind_deg": 71,
#             "wind_gust": 12.95,
#             "wind_speed": 10.71
#         },
#         {
#             "clouds": 61,
#             "dew_point": 294.57,
#             "dt": 1666821600,
#             "feels_like": {
#                 "day": 302.04,
#                 "eve": 299.54,
#                 "morn": 299.29,
#                 "night": 299.18
#             },
#             "humidity": 73,
#             "moon_phase": 0.05,
#             "moonrise": 1666806660,
#             "moonset": 1666847460,
#             "pop": 0.34,
#             "pressure": 1019,
#             "rain": 0.68,
#             "sunrise": 1666801893,
#             "sunset": 1666843137,
#             "temp": {
#                 "day": 300.03,
#                 "eve": 298.95,
#                 "max": 300.07,
#                 "min": 298.57,
#                 "morn": 298.6,
#                 "night": 298.57
#             },
#             "uvi": 7.54,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 63,
#             "wind_gust": 11.89,
#             "wind_speed": 10.06
#         },
#         {
#             "clouds": 37,
#             "dew_point": 293.32,
#             "dt": 1666908000,
#             "feels_like": {
#                 "day": 301.64,
#                 "eve": 298.93,
#                 "morn": 298.37,
#                 "night": 298.72
#             },
#             "humidity": 68,
#             "moon_phase": 0.09,
#             "moonrise": 1666896900,
#             "moonset": 1666936860,
#             "pop": 0.36,
#             "pressure": 1016,
#             "rain": 0.63,
#             "sunrise": 1666888321,
#             "sunset": 1666929499,
#             "temp": {
#                 "day": 300.02,
#                 "eve": 298.44,
#                 "max": 300.1,
#                 "min": 297.81,
#                 "morn": 297.91,
#                 "night": 298.18
#             },
#             "uvi": 7.1,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 43,
#             "wind_gust": 9.59,
#             "wind_speed": 7.87
#         },
#         {
#             "clouds": 13,
#             "dew_point": 293.08,
#             "dt": 1666994400,
#             "feels_like": {
#                 "day": 299.8,
#                 "eve": 299.36,
#                 "morn": 298.31,
#                 "night": 298.81
#             },
#             "humidity": 68,
#             "moon_phase": 0.13,
#             "moonrise": 1666987320,
#             "moonset": 1667026680,
#             "pop": 0.42,
#             "pressure": 1014,
#             "rain": 0.24,
#             "sunrise": 1666974750,
#             "sunset": 1667015862,
#             "temp": {
#                 "day": 299.8,
#                 "eve": 298.83,
#                 "max": 299.81,
#                 "min": 297.8,
#                 "morn": 297.8,
#                 "night": 298.28
#             },
#             "uvi": 7.86,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 65,
#             "wind_gust": 8.26,
#             "wind_speed": 6.86
#         },
#         {
#             "clouds": 18,
#             "dew_point": 293.23,
#             "dt": 1667080800,
#             "feels_like": {
#                 "day": 301.73,
#                 "eve": 299.37,
#                 "morn": 298.57,
#                 "night": 299.29
#             },
#             "humidity": 67,
#             "moon_phase": 0.16,
#             "moonrise": 1667077620,
#             "moonset": 1667116800,
#             "pop": 0.31,
#             "pressure": 1016,
#             "rain": 0.7,
#             "sunrise": 1667061179,
#             "sunset": 1667102226,
#             "temp": {
#                 "day": 300.13,
#                 "eve": 298.84,
#                 "max": 300.2,
#                 "min": 298.03,
#                 "morn": 298.04,
#                 "night": 298.67
#             },
#             "uvi": 7.55,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 64,
#             "wind_gust": 8.98,
#             "wind_speed": 7.54
#         },
#         {
#             "clouds": 11,
#             "dew_point": 293.82,
#             "dt": 1667167200,
#             "feels_like": {
#                 "day": 301.61,
#                 "eve": 299.21,
#                 "morn": 299.22,
#                 "night": 299.26
#             },
#             "humidity": 70,
#             "moon_phase": 0.2,
#             "moonrise": 1667167740,
#             "moonset": 1667207100,
#             "pop": 0.4,
#             "pressure": 1017,
#             "rain": 0.75,
#             "sunrise": 1667147609,
#             "sunset": 1667188591,
#             "temp": {
#                 "day": 299.91,
#                 "eve": 299.21,
#                 "max": 299.91,
#                 "min": 298.35,
#                 "morn": 298.73,
#                 "night": 298.62
#             },
#             "uvi": 8,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 70,
#             "wind_gust": 9.91,
#             "wind_speed": 9.47
#         },
#         {
#             "clouds": 30,
#             "dew_point": 293.49,
#             "dt": 1667253600,
#             "feels_like": {
#                 "day": 301.43,
#                 "eve": 299.3,
#                 "morn": 299.02,
#                 "night": 299.27
#             },
#             "humidity": 69,
#             "moon_phase": 0.25,
#             "moonrise": 1667257440,
#             "moonset": 0,
#             "pop": 0.32,
#             "pressure": 1017,
#             "rain": 1.03,
#             "sunrise": 1667234039,
#             "sunset": 1667274957,
#             "temp": {
#                 "day": 299.84,
#                 "eve": 299.3,
#                 "max": 300.01,
#                 "min": 298.5,
#                 "morn": 298.5,
#                 "night": 298.58
#             },
#             "uvi": 8,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 70,
#             "wind_gust": 12.15,
#             "wind_speed": 9.96
#         },
#         {
#             "clouds": 8,
#             "dew_point": 294.26,
#             "dt": 1667340000,
#             "feels_like": {
#                 "day": 299.73,
#                 "eve": 299.66,
#                 "morn": 298.95,
#                 "night": 299.02
#             },
#             "humidity": 73,
#             "moon_phase": 0.27,
#             "moonrise": 1667346780,
#             "moonset": 1667297400,
#             "pop": 0.28,
#             "pressure": 1017,
#             "rain": 1.17,
#             "sunrise": 1667320470,
#             "sunset": 1667361325,
#             "temp": {
#                 "day": 299.73,
#                 "eve": 299.01,
#                 "max": 299.79,
#                 "min": 298.36,
#                 "morn": 298.36,
#                 "night": 298.4
#             },
#             "uvi": 8,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 70,
#             "wind_gust": 13.39,
#             "wind_speed": 11.06
#         }
#     ],
#     "hourly": [
#         {
#             "clouds": 40,
#             "dew_point": 295.49,
#             "dt": 1666753200,
#             "feels_like": 303.45,
#             "humidity": 73,
#             "pop": 0,
#             "pressure": 1017,
#             "temp": 300.77,
#             "uvi": 0.6,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 67,
#             "wind_gust": 10.9,
#             "wind_speed": 9.16
#         },
#         {
#             "clouds": 40,
#             "dew_point": 295.39,
#             "dt": 1666756800,
#             "feels_like": 302.88,
#             "humidity": 74,
#             "pop": 0,
#             "pressure": 1017,
#             "temp": 300.43,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 69,
#             "wind_gust": 11.3,
#             "wind_speed": 9.01
#         },
#         {
#             "clouds": 38,
#             "dew_point": 295.48,
#             "dt": 1666760400,
#             "feels_like": 302.36,
#             "humidity": 76,
#             "pop": 0,
#             "pressure": 1018,
#             "temp": 300.07,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 70,
#             "wind_gust": 11.34,
#             "wind_speed": 8.9
#         },
#         {
#             "clouds": 34,
#             "dew_point": 295.39,
#             "dt": 1666764000,
#             "feels_like": 299.75,
#             "humidity": 77,
#             "pop": 0.01,
#             "pressure": 1018,
#             "temp": 299.75,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 69,
#             "wind_gust": 11.18,
#             "wind_speed": 8.76
#         },
#         {
#             "clouds": 14,
#             "dew_point": 295.45,
#             "dt": 1666767600,
#             "feels_like": 299.38,
#             "humidity": 79,
#             "pop": 0.02,
#             "pressure": 1019,
#             "temp": 299.38,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 70,
#             "wind_gust": 11.23,
#             "wind_speed": 8.82
#         },
#         {
#             "clouds": 11,
#             "dew_point": 295.17,
#             "dt": 1666771200,
#             "feels_like": 299.73,
#             "humidity": 81,
#             "pop": 0.03,
#             "pressure": 1020,
#             "temp": 298.98,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 71,
#             "wind_gust": 11.17,
#             "wind_speed": 8.66
#         },
#         {
#             "clouds": 13,
#             "dew_point": 295,
#             "dt": 1666774800,
#             "feels_like": 299.71,
#             "humidity": 80,
#             "pop": 0.03,
#             "pressure": 1020,
#             "temp": 298.98,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 66,
#             "wind_gust": 11.46,
#             "wind_speed": 8.68
#         },
#         {
#             "clouds": 14,
#             "dew_point": 295.02,
#             "dt": 1666778400,
#             "feels_like": 299.65,
#             "humidity": 80,
#             "pop": 0.03,
#             "pressure": 1019,
#             "temp": 298.93,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 65,
#             "wind_gust": 11.73,
#             "wind_speed": 9.34
#         },
#         {
#             "clouds": 18,
#             "dew_point": 295.09,
#             "dt": 1666782000,
#             "feels_like": 299.59,
#             "humidity": 81,
#             "pop": 0.11,
#             "pressure": 1019,
#             "temp": 298.85,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 69,
#             "wind_gust": 11.42,
#             "wind_speed": 9.26
#         },
#         {
#             "clouds": 22,
#             "dew_point": 294.87,
#             "dt": 1666785600,
#             "feels_like": 299.53,
#             "humidity": 80,
#             "pop": 0.07,
#             "pressure": 1019,
#             "temp": 298.82,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 72,
#             "wind_gust": 10.98,
#             "wind_speed": 8.98
#         },
#         {
#             "clouds": 23,
#             "dew_point": 294.87,
#             "dt": 1666789200,
#             "feels_like": 299.44,
#             "humidity": 80,
#             "pop": 0.1,
#             "pressure": 1018,
#             "temp": 298.74,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 72,
#             "wind_gust": 11.24,
#             "wind_speed": 9.11
#         },
#         {
#             "clouds": 22,
#             "dew_point": 294.73,
#             "dt": 1666792800,
#             "feels_like": 299.3,
#             "humidity": 80,
#             "pop": 0.2,
#             "pressure": 1018,
#             "rain": {
#                 "1h": 0.11
#             },
#             "temp": 298.61,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 70,
#             "wind_gust": 11.48,
#             "wind_speed": 9.22
#         },
#         {
#             "clouds": 28,
#             "dew_point": 294.74,
#             "dt": 1666796400,
#             "feels_like": 299.3,
#             "humidity": 80,
#             "pop": 0.21,
#             "pressure": 1018,
#             "rain": {
#                 "1h": 0.12
#             },
#             "temp": 298.61,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 66,
#             "wind_gust": 11.52,
#             "wind_speed": 8.7
#         },
#         {
#             "clouds": 43,
#             "dew_point": 294.69,
#             "dt": 1666800000,
#             "feels_like": 299.29,
#             "humidity": 80,
#             "pop": 0.26,
#             "pressure": 1019,
#             "rain": {
#                 "1h": 0.14
#             },
#             "temp": 298.6,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10n",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 64,
#             "wind_gust": 11.29,
#             "wind_speed": 8.52
#         },
#         {
#             "clouds": 48,
#             "dew_point": 294.61,
#             "dt": 1666803600,
#             "feels_like": 299.31,
#             "humidity": 79,
#             "pop": 0.34,
#             "pressure": 1019,
#             "rain": {
#                 "1h": 0.17
#             },
#             "temp": 298.64,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 64,
#             "wind_gust": 11.15,
#             "wind_speed": 8.71
#         },
#         {
#             "clouds": 53,
#             "dew_point": 294.54,
#             "dt": 1666807200,
#             "feels_like": 299.59,
#             "humidity": 78,
#             "pop": 0.29,
#             "pressure": 1020,
#             "rain": {
#                 "1h": 0.14
#             },
#             "temp": 298.92,
#             "uvi": 0.42,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 62,
#             "wind_gust": 11.63,
#             "wind_speed": 9.48
#         },
#         {
#             "clouds": 100,
#             "dew_point": 294.48,
#             "dt": 1666810800,
#             "feels_like": 299.28,
#             "humidity": 76,
#             "pop": 0.12,
#             "pressure": 1020,
#             "temp": 299.28,
#             "uvi": 1.91,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 63,
#             "wind_gust": 11.89,
#             "wind_speed": 9.89
#         },
#         {
#             "clouds": 88,
#             "dew_point": 294.58,
#             "dt": 1666814400,
#             "feels_like": 299.63,
#             "humidity": 75,
#             "pop": 0.01,
#             "pressure": 1020,
#             "temp": 299.63,
#             "uvi": 4.06,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04d",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 63,
#             "wind_gust": 11.73,
#             "wind_speed": 10.06
#         },
#         {
#             "clouds": 74,
#             "dew_point": 294.55,
#             "dt": 1666818000,
#             "feels_like": 301.72,
#             "humidity": 73,
#             "pop": 0,
#             "pressure": 1019,
#             "temp": 299.85,
#             "uvi": 6.3,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 64,
#             "wind_gust": 11.36,
#             "wind_speed": 9.81
#         },
#         {
#             "clouds": 61,
#             "dew_point": 294.57,
#             "dt": 1666821600,
#             "feels_like": 302.04,
#             "humidity": 73,
#             "pop": 0,
#             "pressure": 1019,
#             "temp": 300.03,
#             "uvi": 7.49,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 66,
#             "wind_gust": 10.51,
#             "wind_speed": 9.42
#         },
#         {
#             "clouds": 53,
#             "dew_point": 293.97,
#             "dt": 1666825200,
#             "feels_like": 301.82,
#             "humidity": 70,
#             "pop": 0,
#             "pressure": 1018,
#             "temp": 300.04,
#             "uvi": 7.54,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 62,
#             "wind_gust": 10.04,
#             "wind_speed": 9
#         },
#         {
#             "clouds": 46,
#             "dew_point": 293.49,
#             "dt": 1666828800,
#             "feels_like": 301.72,
#             "humidity": 68,
#             "pop": 0,
#             "pressure": 1017,
#             "temp": 300.07,
#             "uvi": 6.16,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 59,
#             "wind_gust": 9.58,
#             "wind_speed": 8.47
#         },
#         {
#             "clouds": 17,
#             "dew_point": 293.34,
#             "dt": 1666832400,
#             "feels_like": 301.57,
#             "humidity": 68,
#             "pop": 0,
#             "pressure": 1017,
#             "temp": 299.98,
#             "uvi": 4.5,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 57,
#             "wind_gust": 9.61,
#             "wind_speed": 8.47
#         },
#         {
#             "clouds": 15,
#             "dew_point": 293.49,
#             "dt": 1666836000,
#             "feels_like": 299.79,
#             "humidity": 69,
#             "pop": 0,
#             "pressure": 1017,
#             "temp": 299.79,
#             "uvi": 2.17,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 56,
#             "wind_gust": 9.55,
#             "wind_speed": 8.32
#         },
#         {
#             "clouds": 14,
#             "dew_point": 293.89,
#             "dt": 1666839600,
#             "feels_like": 299.42,
#             "humidity": 72,
#             "pop": 0,
#             "pressure": 1017,
#             "temp": 299.42,
#             "uvi": 0.63,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 53,
#             "wind_gust": 9.39,
#             "wind_speed": 8.16
#         },
#         {
#             "clouds": 19,
#             "dew_point": 294.08,
#             "dt": 1666843200,
#             "feels_like": 299.54,
#             "humidity": 75,
#             "pop": 0,
#             "pressure": 1017,
#             "temp": 298.95,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 52,
#             "wind_gust": 9.49,
#             "wind_speed": 7.85
#         },
#         {
#             "clouds": 25,
#             "dew_point": 294.14,
#             "dt": 1666846800,
#             "feels_like": 299.39,
#             "humidity": 76,
#             "pop": 0,
#             "pressure": 1018,
#             "temp": 298.79,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 51,
#             "wind_gust": 9.89,
#             "wind_speed": 7.99
#         },
#         {
#             "clouds": 33,
#             "dew_point": 294.19,
#             "dt": 1666850400,
#             "feels_like": 299.34,
#             "humidity": 77,
#             "pop": 0,
#             "pressure": 1018,
#             "temp": 298.72,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 51,
#             "wind_gust": 9.97,
#             "wind_speed": 8.04
#         },
#         {
#             "clouds": 70,
#             "dew_point": 294.18,
#             "dt": 1666854000,
#             "feels_like": 299.3,
#             "humidity": 77,
#             "pop": 0.06,
#             "pressure": 1019,
#             "temp": 298.68,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 52,
#             "wind_gust": 10.03,
#             "wind_speed": 8.01
#         },
#         {
#             "clouds": 72,
#             "dew_point": 294.16,
#             "dt": 1666857600,
#             "feels_like": 299.2,
#             "humidity": 77,
#             "pop": 0.06,
#             "pressure": 1018,
#             "temp": 298.59,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 57,
#             "wind_gust": 10.05,
#             "wind_speed": 8.05
#         },
#         {
#             "clouds": 81,
#             "dew_point": 294.08,
#             "dt": 1666861200,
#             "feels_like": 299.18,
#             "humidity": 77,
#             "pop": 0,
#             "pressure": 1018,
#             "temp": 298.57,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 58,
#             "wind_gust": 9.64,
#             "wind_speed": 7.81
#         },
#         {
#             "clouds": 86,
#             "dew_point": 293.7,
#             "dt": 1666864800,
#             "feels_like": 299.15,
#             "humidity": 75,
#             "pop": 0,
#             "pressure": 1017,
#             "temp": 298.59,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "overcast clouds",
#                     "icon": "04n",
#                     "id": 804,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 59,
#             "wind_gust": 9.01,
#             "wind_speed": 7.36
#         },
#         {
#             "clouds": 79,
#             "dew_point": 293.27,
#             "dt": 1666868400,
#             "feels_like": 298.92,
#             "humidity": 74,
#             "pop": 0,
#             "pressure": 1017,
#             "temp": 298.41,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 54,
#             "wind_gust": 8.45,
#             "wind_speed": 6.91
#         },
#         {
#             "clouds": 69,
#             "dew_point": 292.91,
#             "dt": 1666872000,
#             "feels_like": 298.69,
#             "humidity": 73,
#             "pop": 0,
#             "pressure": 1016,
#             "temp": 298.22,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 49,
#             "wind_gust": 8.3,
#             "wind_speed": 6.81
#         },
#         {
#             "clouds": 10,
#             "dew_point": 292.61,
#             "dt": 1666875600,
#             "feels_like": 298.49,
#             "humidity": 73,
#             "pop": 0.09,
#             "pressure": 1016,
#             "temp": 298.04,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01n",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind_deg": 51,
#             "wind_gust": 8.48,
#             "wind_speed": 6.79
#         },
#         {
#             "clouds": 13,
#             "dew_point": 292.36,
#             "dt": 1666879200,
#             "feels_like": 298.3,
#             "humidity": 72,
#             "pop": 0.06,
#             "pressure": 1015,
#             "temp": 297.89,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02n",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 53,
#             "wind_gust": 8.45,
#             "wind_speed": 6.42
#         },
#         {
#             "clouds": 34,
#             "dew_point": 292.46,
#             "dt": 1666882800,
#             "feels_like": 298.24,
#             "humidity": 73,
#             "pop": 0.05,
#             "pressure": 1015,
#             "temp": 297.81,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03n",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 50,
#             "wind_gust": 8.3,
#             "wind_speed": 6.14
#         },
#         {
#             "clouds": 51,
#             "dew_point": 292.73,
#             "dt": 1666886400,
#             "feels_like": 298.37,
#             "humidity": 74,
#             "pop": 0.05,
#             "pressure": 1016,
#             "temp": 297.91,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04n",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 46,
#             "wind_gust": 8.47,
#             "wind_speed": 6.32
#         },
#         {
#             "clouds": 60,
#             "dew_point": 292.91,
#             "dt": 1666890000,
#             "feels_like": 298.48,
#             "humidity": 74,
#             "pop": 0.02,
#             "pressure": 1016,
#             "temp": 298.01,
#             "uvi": 0,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 45,
#             "wind_gust": 8.15,
#             "wind_speed": 6.07
#         },
#         {
#             "clouds": 67,
#             "dew_point": 293.07,
#             "dt": 1666893600,
#             "feels_like": 299.07,
#             "humidity": 72,
#             "pop": 0.01,
#             "pressure": 1017,
#             "temp": 298.59,
#             "uvi": 0.53,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 46,
#             "wind_gust": 8.06,
#             "wind_speed": 6.36
#         },
#         {
#             "clouds": 68,
#             "dew_point": 293.1,
#             "dt": 1666897200,
#             "feels_like": 299.21,
#             "humidity": 70,
#             "pop": 0,
#             "pressure": 1017,
#             "temp": 299.21,
#             "uvi": 1.79,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 49,
#             "wind_gust": 8.19,
#             "wind_speed": 7.1
#         },
#         {
#             "clouds": 60,
#             "dew_point": 293.25,
#             "dt": 1666900800,
#             "feels_like": 299.63,
#             "humidity": 69,
#             "pop": 0,
#             "pressure": 1017,
#             "temp": 299.63,
#             "uvi": 3.8,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "broken clouds",
#                     "icon": "04d",
#                     "id": 803,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 54,
#             "wind_gust": 7.9,
#             "wind_speed": 7.05
#         },
#         {
#             "clouds": 43,
#             "dew_point": 293.32,
#             "dt": 1666904400,
#             "feels_like": 301.39,
#             "humidity": 68,
#             "pop": 0.02,
#             "pressure": 1016,
#             "temp": 299.86,
#             "uvi": 5.89,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 53,
#             "wind_gust": 7.73,
#             "wind_speed": 6.94
#         },
#         {
#             "clouds": 37,
#             "dew_point": 293.32,
#             "dt": 1666908000,
#             "feels_like": 301.64,
#             "humidity": 68,
#             "pop": 0.11,
#             "pressure": 1016,
#             "temp": 300.02,
#             "uvi": 7.06,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "scattered clouds",
#                     "icon": "03d",
#                     "id": 802,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 52,
#             "wind_gust": 7.56,
#             "wind_speed": 6.9
#         },
#         {
#             "clouds": 33,
#             "dew_point": 293.26,
#             "dt": 1666911600,
#             "feels_like": 301.68,
#             "humidity": 67,
#             "pop": 0.36,
#             "pressure": 1015,
#             "rain": {
#                 "1h": 0.13
#             },
#             "temp": 300.1,
#             "uvi": 7.1,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 51,
#             "wind_gust": 7.66,
#             "wind_speed": 7.19
#         },
#         {
#             "clouds": 30,
#             "dew_point": 293.16,
#             "dt": 1666915200,
#             "feels_like": 301.41,
#             "humidity": 67,
#             "pop": 0.35,
#             "pressure": 1014,
#             "rain": {
#                 "1h": 0.1
#             },
#             "temp": 299.92,
#             "uvi": 5.8,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "light rain",
#                     "icon": "10d",
#                     "id": 500,
#                     "main": "Rain"
#                 }
#             ],
#             "wind_deg": 46,
#             "wind_gust": 8.06,
#             "wind_speed": 7.5
#         },
#         {
#             "clouds": 11,
#             "dew_point": 293.15,
#             "dt": 1666918800,
#             "feels_like": 299.78,
#             "humidity": 68,
#             "pop": 0.05,
#             "pressure": 1014,
#             "temp": 299.78,
#             "uvi": 4.01,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "few clouds",
#                     "icon": "02d",
#                     "id": 801,
#                     "main": "Clouds"
#                 }
#             ],
#             "wind_deg": 43,
#             "wind_gust": 8.31,
#             "wind_speed": 7.66
#         },
#         {
#             "clouds": 8,
#             "dew_point": 293.07,
#             "dt": 1666922400,
#             "feels_like": 299.46,
#             "humidity": 69,
#             "pop": 0.04,
#             "pressure": 1014,
#             "temp": 299.46,
#             "uvi": 1.94,
#             "visibility": 10000,
#             "weather": [
#                 {
#                     "description": "clear sky",
#                     "icon": "01d",
#                     "id": 800,
#                     "main": "Clear"
#                 }
#             ],
#             "wind_deg": 42,
#             "wind_gust": 8.55,
#             "wind_speed": 7.83
#         }
#     ],
#     "lat": 21.31,
#     "lon": -157.86,
#     "timezone": "Pacific/Honolulu",
#     "timezone_offset": -36000
# }
